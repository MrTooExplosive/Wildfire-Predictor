# %%
import os
import pandas as pd
import numpy as np
from math import floor, ceil, trunc
import datetime as dt

# %%
fire_csv = pd.read_csv('Cleaned_Fire_CSV_Devs_v1.csv')
fire_data_path = os.path.abspath('.')
fire_data_path = fire_data_path + '\\dailyStns'
ca_top_left_lat = 42.06388889
ca_top_left_long = -124.99833333
ca_bottom_right_lat = 33.36361111
ca_bottom_right_long = -113.77916667

# %%
fire_csv
# Out:
#         ID  AcresBurned  ArchiveYear     Counties          Extinguished  \
# 0        0     257314.0         2013     Tuolumne  2013-09-06T18:30:00Z
# 1        1      30274.0         2013  Los Angeles  2013-06-08T18:30:00Z
# 2        2      27531.0         2013    Riverside  2013-07-30T18:00:00Z
# 3        4      24251.0         2013      Ventura  2013-05-11T06:30:00Z
# 4        6      20292.0         2013    Riverside  2013-08-12T18:00:00Z
# ...    ...          ...          ...          ...                   ...
# 1246  1628         10.0         2019        Butte                   NaN
# 1247  1629         10.0         2019     Siskiyou  2019-06-21T14:23:00Z
# 1248  1630         10.0         2019        Butte  2019-05-08T08:47:00Z
# 1249  1631          9.0         2019    Riverside  2019-10-10T18:11:00Z
# 1250  1632          2.0         2019       Nevada  2019-06-28T17:33:00Z
#
#       Fatalities  Injuries   Latitude   Longitude             Name  \
# 0            0.0       0.0  37.857000 -120.086000         Rim Fire
# 1            0.0       0.0  34.585595 -118.423176  Powerhouse Fire
# 2            0.0       0.0  33.709500 -116.728850    Mountain Fire
# 3            0.0      10.0   0.000000    0.000000     Springs Fire
# 4            0.0      26.0  33.861570 -116.904270      Silver Fire
# ...          ...       ...        ...         ...              ...
# 1246         0.0       0.0  39.423833 -121.579738       Moms Fire
# 1247         0.0       0.0  41.946220 -122.401570    IronGate Fire
# 1248         0.0       0.0  39.839580 -121.957000        Cana Fire
# 1249         0.0       0.0  33.827979 -117.499619       Eagle Fire
# 1250         0.0       0.0  39.409722 -121.000556        Long Fire
#
#                    Started
# 0     2013-08-17T15:25:00Z
# 1     2013-05-30T15:28:00Z
# 2     2013-07-15T13:43:00Z
# 3     2013-05-02T07:01:00Z
# 4     2013-08-07T14:05:00Z
# ...                    ...
# 1246  2019-07-23T14:41:00Z
# 1247  2019-06-16T20:33:00Z
# 1248  2019-04-30T12:20:00Z
# 1249  2019-10-10T12:08:00Z
# 1250  2019-06-28T15:03:04Z
#
# [1251 rows x 11 columns]

# %%
lat_update_fire_csv = fire_csv.loc[fire_csv['Latitude']>=ca_bottom_right_lat].loc[fire_csv['Latitude']<=ca_top_left_lat]
long_update_fire_csv = lat_update_fire_csv.loc[lat_update_fire_csv['Longitude']>=ca_top_left_long].loc[lat_update_fire_csv['Longitude']<=ca_bottom_right_long]
long_update_fire_csv.to_csv('Updated_long_late_fire_data.csv')

# %%
fire_data_path
# Out:
# 'c:\\Users\\profc\\Desktop\\Wildfire-Predictor\\dailyStns'

# %%
start_year = 2013
end_year = 2020
weather_csv_list = []
while start_year <= end_year:
    weather_csv_list = weather_csv_list + os.listdir(fire_data_path + str(start_year))
    start_year += 1
#if '.ipynb_checkpoints' in weather_csv_list:

# %%
weather_csv_list
# Out:
# ['2013daily002.csv',
#  '2013daily002_new.csv',
#  '2013daily005.csv',
#  '2013daily005_new.csv',
#  '2013daily006.csv',
#  '2013daily006_new.csv',
#  '2013daily007.csv',
#  '2013daily007_new.csv',
#  '2013daily008.csv',
#  '2013daily008_new.csv',
#  '2013daily012.csv',
#  '2013daily012_new.csv',
#  '2013daily013.csv',
#  '2013daily013_new.csv',
#  '2013daily015.csv',
#  '2013daily015_new.csv',
#  '2013daily019.csv',
#  '2013daily019_new.csv',
#  '2013daily021.csv',
#  '2013daily021_new.csv',
#  '2013daily032.csv',
#  '2013daily032_new.csv',
#  '2013daily035.csv',
#  '2013daily035_new.csv',
#  '2013daily039.csv',
#  '2013daily039_new.csv',
#  '2013daily041.csv',
#  '2013daily041_new.csv',
#  '2013daily043.csv',
#  '2013daily043_new.csv',
#  '2013daily044.csv',
#  '2013daily044_new.csv',
#  '2013daily047.csv',
#  '2013daily047_new.csv',
#  '2013daily052.csv',
#  '2013daily052_new.csv',
#  '2013daily054.csv',
#  '2013daily054_new.csv',
#  '2013daily056.csv',
#  '2013daily056_new.csv',
#  '2013daily057.csv',
#  '2013daily057_new.csv',
#  '2013daily062.csv',
#  '2013daily062_new.csv',
#  '2013daily064.csv',
#  '2013daily064_new.csv',
#  '2013daily068.csv',
#  '2013daily068_new.csv',
#  '2013daily070.csv',
#  '2013daily070_new.csv',
#  '2013daily071.csv',
#  '2013daily071_new.csv',
#  '2013daily075.csv',
#  '2013daily075_new.csv',
#  '2013daily077.csv',
#  '2013daily077_new.csv',
#  '2013daily078.csv',
#  '2013daily078_new.csv',
#  '2013daily080.csv',
#  '2013daily080_new.csv',
#  '2013daily083.csv',
#  '2013daily083_new.csv',
#  '2013daily084.csv',
#  '2013daily084_new.csv',
#  '2013daily085.csv',
#  '2013daily085_new.csv',
#  '2013daily086.csv',
#  '2013daily086_new.csv',
#  '2013daily087.csv',
#  '2013daily087_new.csv',
#  '2013daily088.csv',
#  '2013daily088_new.csv',
#  '2013daily090.csv',
#  '2013daily090_new.csv',
#  '2013daily091.csv',
#  '2013daily091_new.csv',
#  '2013daily092.csv',
#  '2013daily092_new.csv',
#  '2013daily094.csv',
#  '2013daily094_new.csv',
#  '2013daily099.csv',
#  '2013daily099_new.csv',
#  '2013daily103.csv',
#  '2013daily103_new.csv',
#  '2013daily104.csv',
#  '2013daily104_new.csv',
#  '2013daily105.csv',
#  '2013daily105_new.csv',
#  '2013daily106.csv',
#  '2013daily106_new.csv',
#  '2013daily107.csv',
#  '2013daily107_new.csv',
#  '2013daily109.csv',
#  '2013daily109_new.csv',
#  '2013daily111.csv',
#  '2013daily111_new.csv',
#  '2013daily113.csv',
#  '2013daily113_new.csv',
#  '2013daily114.csv',
#  '2013daily114_new.csv',
#  '2013daily116.csv',
#  '2013daily116_new.csv',
#  '2013daily117.csv',
#  '2013daily117_new.csv',
#  '2013daily118.csv',
#  '2013daily118_new.csv',
#  '2013daily121.csv',
#  '2013daily121_new.csv',
#  '2013daily124.csv',
#  '2013daily124_new.csv',
#  '2013daily125.csv',
#  '2013daily125_new.csv',
#  '2013daily126.csv',
#  '2013daily126_new.csv',
#  '2013daily128.csv',
#  '2013daily128_new.csv',
#  '2013daily129.csv',
#  '2013daily129_new.csv',
#  '2013daily131.csv',
#  '2013daily131_new.csv',
#  '2013daily133.csv',
#  '2013daily133_new.csv',
#  '2013daily135.csv',
#  '2013daily135_new.csv',
#  '2013daily136.csv',
#  '2013daily136_new.csv',
#  '2013daily138.csv',
#  '2013daily138_new.csv',
#  '2013daily139.csv',
#  '2013daily139_new.csv',
#  '2013daily140.csv',
#  '2013daily140_new.csv',
#  '2013daily142.csv',
#  '2013daily142_new.csv',
#  '2013daily143.csv',
#  '2013daily143_new.csv',
#  '2013daily144.csv',
#  '2013daily144_new.csv',
#  '2013daily146.csv',
#  '2013daily146_new.csv',
#  '2013daily147.csv',
#  '2013daily147_new.csv',
#  '2013daily148.csv',
#  '2013daily148_new.csv',
#  '2013daily150.csv',
#  '2013daily150_new.csv',
#  '2013daily151.csv',
#  '2013daily151_new.csv',
#  '2013daily152.csv',
#  '2013daily152_new.csv',
#  '2013daily153.csv',
#  '2013daily153_new.csv',
#  '2013daily155.csv',
#  '2013daily155_new.csv',
#  '2013daily156.csv',
#  '2013daily156_new.csv',
#  '2013daily157.csv',
#  '2013daily157_new.csv',
#  '2013daily158.csv',
#  '2013daily158_new.csv',
#  '2013daily159.csv',
#  '2013daily159_new.csv',
#  '2013daily160.csv',
#  '2013daily160_new.csv',
#  '2013daily161.csv',
#  '2013daily161_new.csv',
#  '2013daily163.csv',
#  '2013daily163_new.csv',
#  '2013daily165.csv',
#  '2013daily165_new.csv',
#  '2013daily166.csv',
#  '2013daily166_new.csv',
#  '2013daily167.csv',
#  '2013daily167_new.csv',
#  '2013daily169.csv',
#  '2013daily169_new.csv',
#  '2013daily170.csv',
#  '2013daily170_new.csv',
#  '2013daily171.csv',
#  '2013daily171_new.csv',
#  '2013daily173.csv',
#  '2013daily173_new.csv',
#  '2013daily174.csv',
#  '2013daily174_new.csv',
#  '2013daily175.csv',
#  '2013daily175_new.csv',
#  '2013daily178.csv',
#  '2013daily178_new.csv',
#  '2013daily179.csv',
#  '2013daily179_new.csv',
#  '2013daily181.csv',
#  '2013daily181_new.csv',
#  '2013daily182.csv',
#  '2013daily182_new.csv',
#  '2013daily183.csv',
#  '2013daily183_new.csv',
#  '2013daily184.csv',
#  '2013daily184_new.csv',
#  '2013daily186.csv',
#  '2013daily186_new.csv',
#  '2013daily187.csv',
#  '2013daily187_new.csv',
#  '2013daily188.csv',
#  '2013daily188_new.csv',
#  '2013daily189.csv',
#  '2013daily189_new.csv',
#  '2013daily190.csv',
#  '2013daily190_new.csv',
#  '2013daily191.csv',
#  '2013daily191_new.csv',
#  '2013daily192.csv',
#  '2013daily192_new.csv',
#  '2013daily193.csv',
#  '2013daily193_new.csv',
#  '2013daily194.csv',
#  '2013daily194_new.csv',
#  '2013daily195.csv',
#  '2013daily195_new.csv',
#  '2013daily196.csv',
#  '2013daily196_new.csv',
#  '2013daily197.csv',
#  '2013daily197_new.csv',
#  '2013daily198.csv',
#  '2013daily198_new.csv',
#  '2013daily199.csv',
#  '2013daily199_new.csv',
#  '2013daily200.csv',
#  '2013daily200_new.csv',
#  '2013daily201.csv',
#  '2013daily201_new.csv',
#  '2013daily202.csv',
#  '2013daily202_new.csv',
#  '2013daily203.csv',
#  '2013daily203_new.csv',
#  '2013daily204.csv',
#  '2013daily204_new.csv',
#  '2013daily205.csv',
#  '2013daily205_new.csv',
#  '2013daily206.csv',
#  '2013daily206_new.csv',
#  '2013daily207.csv',
#  '2013daily207_new.csv',
#  '2013daily208.csv',
#  '2013daily208_new.csv',
#  '2013daily209.csv',
#  '2013daily209_new.csv',
#  '2013daily210.csv',
#  '2013daily210_new.csv',
#  '2013daily211.csv',
#  '2013daily211_new.csv',
#  '2013daily212.csv',
#  '2013daily212_new.csv',
#  '2013daily213.csv',
#  '2013daily213_new.csv',
#  '2013daily214.csv',
#  '2013daily214_new.csv',
#  '2013daily215.csv',
#  '2013daily215_new.csv',
#  '2013daily216.csv',
#  '2013daily216_new.csv',
#  '2013daily218.csv',
#  '2013daily218_new.csv',
#  '2013daily219.csv',
#  '2013daily219_new.csv',
#  '2013daily220.csv',
#  '2013daily220_new.csv',
#  '2013daily221.csv',
#  '2013daily221_new.csv',
#  '2013daily224.csv',
#  '2013daily224_new.csv',
#  '2013daily226.csv',
#  '2013daily226_new.csv',
#  '2013daily227.csv',
#  '2013daily227_new.csv',
#  '2013daily228.csv',
#  '2013daily228_new.csv',
#  '2013daily229.csv',
#  '2013daily229_new.csv',
#  '2013daily230.csv',
#  '2013daily230_new.csv',
#  '2013daily231.csv',
#  '2013daily231_new.csv',
#  '2013daily232.csv',
#  '2013daily232_new.csv',
#  '2013daily233.csv',
#  '2013daily233_new.csv',
#  '2013daily235.csv',
#  '2013daily235_new.csv',
#  '2013daily237.csv',
#  '2013daily237_new.csv',
#  '2013daily238.csv',
#  '2013daily238_new.csv',
#  '2013daily240.csv',
#  '2013daily240_new.csv',
#  '2014daily002.csv',
#  '2014daily002_new.csv',
#  '2014daily005.csv',
#  '2014daily005_new.csv',
#  '2014daily006.csv',
#  '2014daily006_new.csv',
#  '2014daily007.csv',
#  '2014daily007_new.csv',
#  '2014daily012.csv',
#  '2014daily012_new.csv',
#  '2014daily013.csv',
#  '2014daily013_new.csv',
#  '2014daily015.csv',
#  '2014daily015_new.csv',
#  '2014daily019.csv',
#  '2014daily019_new.csv',
#  '2014daily032.csv',
#  '2014daily032_new.csv',
#  '2014daily035.csv',
#  '2014daily035_new.csv',
#  '2014daily039.csv',
#  '2014daily039_new.csv',
#  '2014daily041.csv',
#  '2014daily041_new.csv',
#  '2014daily043.csv',
#  '2014daily043_new.csv',
#  '2014daily044.csv',
#  '2014daily044_new.csv',
#  '2014daily047.csv',
#  '2014daily047_new.csv',
#  '2014daily052.csv',
#  '2014daily052_new.csv',
#  '2014daily054.csv',
#  '2014daily054_new.csv',
#  '2014daily056.csv',
#  '2014daily056_new.csv',
#  '2014daily057.csv',
#  '2014daily057_new.csv',
#  '2014daily062.csv',
#  '2014daily062_new.csv',
#  '2014daily064.csv',
#  '2014daily064_new.csv',
#  '2014daily068.csv',
#  '2014daily068_new.csv',
#  '2014daily070.csv',
#  '2014daily070_new.csv',
#  '2014daily071.csv',
#  '2014daily071_new.csv',
#  '2014daily075.csv',
#  '2014daily075_new.csv',
#  '2014daily077.csv',
#  '2014daily077_new.csv',
#  '2014daily078.csv',
#  '2014daily078_new.csv',
#  '2014daily080.csv',
#  '2014daily080_new.csv',
#  '2014daily083.csv',
#  '2014daily083_new.csv',
#  '2014daily084.csv',
#  '2014daily084_new.csv',
#  '2014daily085.csv',
#  '2014daily085_new.csv',
#  '2014daily086.csv',
#  '2014daily086_new.csv',
#  '2014daily087.csv',
#  '2014daily087_new.csv',
#  '2014daily088.csv',
#  '2014daily088_new.csv',
#  '2014daily090.csv',
#  '2014daily090_new.csv',
#  '2014daily091.csv',
#  '2014daily091_new.csv',
#  '2014daily092.csv',
#  '2014daily092_new.csv',
#  '2014daily094.csv',
#  '2014daily094_new.csv',
#  '2014daily099.csv',
#  '2014daily099_new.csv',
#  '2014daily103.csv',
#  '2014daily103_new.csv',
#  '2014daily104.csv',
#  '2014daily104_new.csv',
#  '2014daily105.csv',
#  '2014daily105_new.csv',
#  '2014daily106.csv',
#  '2014daily106_new.csv',
#  '2014daily107.csv',
#  '2014daily107_new.csv',
#  '2014daily109.csv',
#  '2014daily109_new.csv',
#  '2014daily111.csv',
#  '2014daily111_new.csv',
#  '2014daily113.csv',
#  '2014daily113_new.csv',
#  '2014daily114.csv',
#  '2014daily114_new.csv',
#  '2014daily116.csv',
#  '2014daily116_new.csv',
#  '2014daily117.csv',
#  '2014daily117_new.csv',
#  '2014daily121.csv',
#  '2014daily121_new.csv',
#  '2014daily124.csv',
#  '2014daily124_new.csv',
#  '2014daily125.csv',
#  '2014daily125_new.csv',
#  '2014daily126.csv',
#  '2014daily126_new.csv',
#  '2014daily129.csv',
#  '2014daily129_new.csv',
#  '2014daily131.csv',
#  '2014daily131_new.csv',
#  '2014daily133.csv',
#  '2014daily133_new.csv',
#  '2014daily135.csv',
#  '2014daily135_new.csv',
#  '2014daily136.csv',
#  '2014daily136_new.csv',
#  '2014daily138.csv',
#  '2014daily138_new.csv',
#  '2014daily139.csv',
#  '2014daily139_new.csv',
#  '2014daily140.csv',
#  '2014daily140_new.csv',
#  '2014daily142.csv',
#  '2014daily142_new.csv',
#  '2014daily143.csv',
#  '2014daily143_new.csv',
#  '2014daily144.csv',
#  '2014daily144_new.csv',
#  '2014daily146.csv',
#  '2014daily146_new.csv',
#  '2014daily147.csv',
#  '2014daily147_new.csv',
#  '2014daily148.csv',
#  '2014daily148_new.csv',
#  '2014daily150.csv',
#  '2014daily150_new.csv',
#  '2014daily151.csv',
#  '2014daily151_new.csv',
#  '2014daily152.csv',
#  '2014daily152_new.csv',
#  '2014daily153.csv',
#  '2014daily153_new.csv',
#  '2014daily155.csv',
#  '2014daily155_new.csv',
#  '2014daily156.csv',
#  '2014daily156_new.csv',
#  '2014daily157.csv',
#  '2014daily157_new.csv',
#  '2014daily158.csv',
#  '2014daily158_new.csv',
#  '2014daily159.csv',
#  '2014daily159_new.csv',
#  '2014daily160.csv',
#  '2014daily160_new.csv',
#  '2014daily161.csv',
#  '2014daily161_new.csv',
#  '2014daily163.csv',
#  '2014daily163_new.csv',
#  '2014daily165.csv',
#  '2014daily165_new.csv',
#  '2014daily166.csv',
#  '2014daily166_new.csv',
#  '2014daily167.csv',
#  '2014daily167_new.csv',
#  '2014daily169.csv',
#  '2014daily169_new.csv',
#  '2014daily170.csv',
#  '2014daily170_new.csv',
#  '2014daily171.csv',
#  '2014daily171_new.csv',
#  '2014daily173.csv',
#  '2014daily173_new.csv',
#  '2014daily174.csv',
#  '2014daily174_new.csv',
#  '2014daily175.csv',
#  '2014daily175_new.csv',
#  '2014daily178.csv',
#  '2014daily178_new.csv',
#  '2014daily179.csv',
#  '2014daily179_new.csv',
#  '2014daily181.csv',
#  '2014daily181_new.csv',
#  '2014daily182.csv',
#  '2014daily182_new.csv',
#  '2014daily183.csv',
#  '2014daily183_new.csv',
#  '2014daily184.csv',
#  '2014daily184_new.csv',
#  '2014daily187.csv',
#  '2014daily187_new.csv',
#  '2014daily188.csv',
#  '2014daily188_new.csv',
#  '2014daily189.csv',
#  '2014daily189_new.csv',
#  '2014daily190.csv',
#  '2014daily190_new.csv',
#  '2014daily191.csv',
#  '2014daily191_new.csv',
#  '2014daily192.csv',
#  '2014daily192_new.csv',
#  '2014daily193.csv',
#  '2014daily193_new.csv',
#  '2014daily194.csv',
#  '2014daily194_new.csv',
#  '2014daily195.csv',
#  '2014daily195_new.csv',
#  '2014daily196.csv',
#  '2014daily196_new.csv',
#  '2014daily197.csv',
#  '2014daily197_new.csv',
#  '2014daily198.csv',
#  '2014daily198_new.csv',
#  '2014daily199.csv',
#  '2014daily199_new.csv',
#  '2014daily200.csv',
#  '2014daily200_new.csv',
#  '2014daily201.csv',
#  '2014daily201_new.csv',
#  '2014daily202.csv',
#  '2014daily202_new.csv',
#  '2014daily203.csv',
#  '2014daily203_new.csv',
#  '2014daily204.csv',
#  '2014daily204_new.csv',
#  '2014daily205.csv',
#  '2014daily205_new.csv',
#  '2014daily206.csv',
#  '2014daily206_new.csv',
#  '2014daily207.csv',
#  '2014daily207_new.csv',
#  '2014daily208.csv',
#  '2014daily208_new.csv',
#  '2014daily209.csv',
#  '2014daily209_new.csv',
#  '2014daily210.csv',
#  '2014daily210_new.csv',
#  '2014daily211.csv',
#  '2014daily211_new.csv',
#  '2014daily212.csv',
#  '2014daily212_new.csv',
#  '2014daily213.csv',
#  '2014daily213_new.csv',
#  '2014daily214.csv',
#  '2014daily214_new.csv',
#  '2014daily215.csv',
#  '2014daily215_new.csv',
#  '2014daily216.csv',
#  '2014daily216_new.csv',
#  '2014daily217.csv',
#  '2014daily217_new.csv',
#  '2014daily218.csv',
#  '2014daily218_new.csv',
#  '2014daily219.csv',
#  '2014daily219_new.csv',
#  '2014daily220.csv',
#  '2014daily220_new.csv',
#  '2014daily221.csv',
#  '2014daily221_new.csv',
#  '2014daily222.csv',
#  '2014daily222_new.csv',
#  '2014daily224.csv',
#  '2014daily224_new.csv',
#  '2014daily226.csv',
#  '2014daily226_new.csv',
#  '2014daily227.csv',
#  '2014daily227_new.csv',
#  '2014daily228.csv',
#  '2014daily228_new.csv',
#  '2014daily229.csv',
#  '2014daily229_new.csv',
#  '2014daily230.csv',
#  '2014daily230_new.csv',
#  '2014daily231.csv',
#  '2014daily231_new.csv',
#  '2014daily232.csv',
#  '2014daily232_new.csv',
#  '2014daily233.csv',
#  '2014daily233_new.csv',
#  '2014daily235.csv',
#  '2014daily235_new.csv',
#  '2014daily237.csv',
#  '2014daily237_new.csv',
#  '2014daily238.csv',
#  '2014daily238_new.csv',
#  '2014daily240.csv',
#  '2014daily240_new.csv',
#  '2015daily002.csv',
#  '2015daily002_new.csv',
#  '2015daily005.csv',
#  '2015daily005_new.csv',
#  '2015daily006.csv',
#  '2015daily006_new.csv',
#  '2015daily007.csv',
#  '2015daily007_new.csv',
#  '2015daily012.csv',
#  '2015daily012_new.csv',
#  '2015daily013.csv',
#  '2015daily013_new.csv',
#  '2015daily015.csv',
#  '2015daily015_new.csv',
#  '2015daily019.csv',
#  '2015daily019_new.csv',
#  '2015daily021.csv',
#  '2015daily021_new.csv',
#  '2015daily032.csv',
#  '2015daily032_new.csv',
#  '2015daily035.csv',
#  '2015daily035_new.csv',
#  '2015daily039.csv',
#  '2015daily039_new.csv',
#  '2015daily041.csv',
#  '2015daily041_new.csv',
#  '2015daily043.csv',
#  '2015daily043_new.csv',
#  '2015daily044.csv',
#  '2015daily044_new.csv',
#  '2015daily047.csv',
#  '2015daily047_new.csv',
#  '2015daily052.csv',
#  '2015daily052_new.csv',
#  '2015daily054.csv',
#  '2015daily054_new.csv',
#  '2015daily056.csv',
#  '2015daily056_new.csv',
#  '2015daily057.csv',
#  '2015daily057_new.csv',
#  '2015daily062.csv',
#  '2015daily062_new.csv',
#  '2015daily064.csv',
#  '2015daily064_new.csv',
#  '2015daily068.csv',
#  '2015daily068_new.csv',
#  '2015daily070.csv',
#  '2015daily070_new.csv',
#  '2015daily071.csv',
#  '2015daily071_new.csv',
#  '2015daily075.csv',
#  '2015daily075_new.csv',
#  '2015daily077.csv',
#  '2015daily077_new.csv',
#  '2015daily078.csv',
#  '2015daily078_new.csv',
#  '2015daily080.csv',
#  '2015daily080_new.csv',
#  '2015daily083.csv',
#  '2015daily083_new.csv',
#  '2015daily084.csv',
#  '2015daily084_new.csv',
#  '2015daily085.csv',
#  '2015daily085_new.csv',
#  '2015daily086.csv',
#  '2015daily086_new.csv',
#  '2015daily087.csv',
#  '2015daily087_new.csv',
#  '2015daily088.csv',
#  '2015daily088_new.csv',
#  '2015daily090.csv',
#  '2015daily090_new.csv',
#  '2015daily091.csv',
#  '2015daily091_new.csv',
#  '2015daily092.csv',
#  '2015daily092_new.csv',
#  '2015daily094.csv',
#  '2015daily094_new.csv',
#  '2015daily099.csv',
#  '2015daily099_new.csv',
#  '2015daily103.csv',
#  '2015daily103_new.csv',
#  '2015daily104.csv',
#  '2015daily104_new.csv',
#  '2015daily105.csv',
#  '2015daily105_new.csv',
#  '2015daily106.csv',
#  '2015daily106_new.csv',
#  '2015daily107.csv',
#  '2015daily107_new.csv',
#  '2015daily109.csv',
#  '2015daily109_new.csv',
#  '2015daily111.csv',
#  '2015daily111_new.csv',
#  '2015daily113.csv',
#  '2015daily113_new.csv',
#  '2015daily114.csv',
#  '2015daily114_new.csv',
#  '2015daily116.csv',
#  '2015daily116_new.csv',
#  '2015daily117.csv',
#  '2015daily117_new.csv',
#  '2015daily121.csv',
#  '2015daily121_new.csv',
#  '2015daily124.csv',
#  '2015daily124_new.csv',
#  '2015daily125.csv',
#  '2015daily125_new.csv',
#  '2015daily126.csv',
#  '2015daily126_new.csv',
#  '2015daily129.csv',
#  '2015daily129_new.csv',
#  '2015daily131.csv',
#  '2015daily131_new.csv',
#  '2015daily135.csv',
#  '2015daily135_new.csv',
#  '2015daily136.csv',
#  '2015daily136_new.csv',
#  '2015daily138.csv',
#  '2015daily138_new.csv',
#  '2015daily139.csv',
#  '2015daily139_new.csv',
#  '2015daily140.csv',
#  '2015daily140_new.csv',
#  '2015daily142.csv',
#  '2015daily142_new.csv',
#  '2015daily143.csv',
#  '2015daily143_new.csv',
#  '2015daily144.csv',
#  '2015daily144_new.csv',
#  '2015daily146.csv',
#  '2015daily146_new.csv',
#  '2015daily147.csv',
#  '2015daily147_new.csv',
#  '2015daily148.csv',
#  '2015daily148_new.csv',
#  '2015daily150.csv',
#  '2015daily150_new.csv',
#  '2015daily151.csv',
#  '2015daily151_new.csv',
#  '2015daily152.csv',
#  '2015daily152_new.csv',
#  '2015daily153.csv',
#  '2015daily153_new.csv',
#  '2015daily155.csv',
#  '2015daily155_new.csv',
#  '2015daily156.csv',
#  '2015daily156_new.csv',
#  '2015daily157.csv',
#  '2015daily157_new.csv',
#  '2015daily158.csv',
#  '2015daily158_new.csv',
#  '2015daily159.csv',
#  '2015daily159_new.csv',
#  '2015daily160.csv',
#  '2015daily160_new.csv',
#  '2015daily161.csv',
#  '2015daily161_new.csv',
#  '2015daily163.csv',
#  '2015daily163_new.csv',
#  '2015daily165.csv',
#  '2015daily165_new.csv',
#  '2015daily167.csv',
#  '2015daily167_new.csv',
#  '2015daily169.csv',
#  '2015daily169_new.csv',
#  '2015daily170.csv',
#  '2015daily170_new.csv',
#  '2015daily171.csv',
#  '2015daily171_new.csv',
#  '2015daily173.csv',
#  '2015daily173_new.csv',
#  '2015daily174.csv',
#  '2015daily174_new.csv',
#  '2015daily175.csv',
#  '2015daily175_new.csv',
#  '2015daily178.csv',
#  '2015daily178_new.csv',
#  '2015daily179.csv',
#  '2015daily179_new.csv',
#  '2015daily181.csv',
#  '2015daily181_new.csv',
#  '2015daily182.csv',
#  '2015daily182_new.csv',
#  '2015daily183.csv',
#  '2015daily183_new.csv',
#  '2015daily184.csv',
#  '2015daily184_new.csv',
#  '2015daily186.csv',
#  '2015daily186_new.csv',
#  '2015daily187.csv',
#  '2015daily187_new.csv',
#  '2015daily188.csv',
#  '2015daily188_new.csv',
#  '2015daily189.csv',
#  '2015daily189_new.csv',
#  '2015daily190.csv',
#  '2015daily190_new.csv',
#  '2015daily191.csv',
#  '2015daily191_new.csv',
#  '2015daily192.csv',
#  '2015daily192_new.csv',
#  '2015daily193.csv',
#  '2015daily193_new.csv',
#  '2015daily194.csv',
#  '2015daily194_new.csv',
#  '2015daily195.csv',
#  '2015daily195_new.csv',
#  '2015daily196.csv',
#  '2015daily196_new.csv',
#  '2015daily197.csv',
#  '2015daily197_new.csv',
#  '2015daily198.csv',
#  '2015daily198_new.csv',
#  '2015daily199.csv',
#  '2015daily199_new.csv',
#  '2015daily200.csv',
#  '2015daily200_new.csv',
#  '2015daily201.csv',
#  '2015daily201_new.csv',
#  '2015daily202.csv',
#  '2015daily202_new.csv',
#  '2015daily203.csv',
#  '2015daily203_new.csv',
#  '2015daily204.csv',
#  '2015daily204_new.csv',
#  '2015daily205.csv',
#  '2015daily205_new.csv',
#  '2015daily206.csv',
#  '2015daily206_new.csv',
#  '2015daily207.csv',
#  '2015daily207_new.csv',
#  '2015daily208.csv',
#  '2015daily208_new.csv',
#  '2015daily209.csv',
#  '2015daily209_new.csv',
#  '2015daily210.csv',
#  '2015daily210_new.csv',
#  '2015daily211.csv',
#  '2015daily211_new.csv',
#  '2015daily212.csv',
#  '2015daily212_new.csv',
#  '2015daily213.csv',
#  '2015daily213_new.csv',
#  '2015daily214.csv',
#  '2015daily214_new.csv',
#  '2015daily215.csv',
#  '2015daily215_new.csv',
#  '2015daily216.csv',
#  '2015daily216_new.csv',
#  '2015daily217.csv',
#  '2015daily217_new.csv',
#  '2015daily218.csv',
#  '2015daily218_new.csv',
#  '2015daily219.csv',
#  '2015daily219_new.csv',
#  '2015daily220.csv',
#  '2015daily220_new.csv',
#  '2015daily221.csv',
#  '2015daily221_new.csv',
#  '2015daily222.csv',
#  '2015daily222_new.csv',
#  '2015daily224.csv',
#  '2015daily224_new.csv',
#  '2015daily225.csv',
#  '2015daily225_new.csv',
#  '2015daily226.csv',
#  '2015daily226_new.csv',
#  '2015daily227.csv',
#  '2015daily227_new.csv',
#  '2015daily228.csv',
#  '2015daily228_new.csv',
#  '2015daily229.csv',
#  '2015daily229_new.csv',
#  '2015daily230.csv',
#  '2015daily230_new.csv',
#  '2015daily231.csv',
#  '2015daily231_new.csv',
#  '2015daily232.csv',
#  '2015daily232_new.csv',
#  '2015daily233.csv',
#  '2015daily233_new.csv',
#  '2015daily234.csv',
#  '2015daily234_new.csv',
#  '2015daily235.csv',
#  '2015daily235_new.csv',
#  '2015daily236.csv',
#  '2015daily236_new.csv',
#  '2015daily237.csv',
#  '2015daily237_new.csv',
#  '2015daily238.csv',
#  '2015daily238_new.csv',
#  '2015daily239.csv',
#  '2015daily239_new.csv',
#  '2015daily240.csv',
#  '2015daily240_new.csv',
#  '2015daily241.csv',
#  '2015daily241_new.csv',
#  '2015daily242.csv',
#  '2015daily242_new.csv',
#  '2015daily244.csv',
#  '2015daily244_new.csv',
#  '2015daily245.csv',
#  '2015daily245_new.csv',
#  '2016daily002_new.csv',
#  '2016daily005_new.csv',
#  '2016daily006_new.csv',
#  '2016daily007_new.csv',
#  '2016daily012_new.csv',
#  '2016daily013_new.csv',
#  '2016daily015_new.csv',
#  '2016daily019_new.csv',
#  '2016daily021_new.csv',
#  '2016daily035_new.csv',
#  '2016daily039_new.csv',
#  '2016daily041_new.csv',
#  '2016daily043_new.csv',
#  '2016daily044_new.csv',
#  '2016daily047_new.csv',
#  '2016daily052_new.csv',
#  '2016daily054_new.csv',
#  '2016daily056_new.csv',
#  '2016daily057_new.csv',
#  '2016daily062_new.csv',
#  '2016daily064_new.csv',
#  '2016daily068_new.csv',
#  '2016daily070_new.csv',
#  '2016daily071_new.csv',
#  '2016daily075_new.csv',
#  '2016daily077_new.csv',
#  '2016daily078_new.csv',
#  '2016daily080_new.csv',
#  '2016daily083_new.csv',
#  '2016daily084_new.csv',
#  '2016daily086_new.csv',
#  '2016daily087_new.csv',
#  '2016daily088_new.csv',
#  '2016daily090_new.csv',
#  '2016daily091_new.csv',
#  '2016daily092_new.csv',
#  '2016daily099_new.csv',
#  '2016daily103_new.csv',
#  '2016daily104_new.csv',
#  '2016daily105_new.csv',
#  '2016daily106_new.csv',
#  '2016daily107_new.csv',
#  '2016daily109_new.csv',
#  '2016daily111_new.csv',
#  '2016daily113_new.csv',
#  '2016daily114_new.csv',
#  '2016daily116_new.csv',
#  '2016daily117_new.csv',
#  '2016daily121_new.csv',
#  '2016daily124_new.csv',
#  '2016daily125_new.csv',
#  '2016daily126_new.csv',
#  '2016daily129_new.csv',
#  '2016daily131_new.csv',
#  '2016daily135_new.csv',
#  '2016daily136_new.csv',
#  '2016daily139_new.csv',
#  '2016daily140_new.csv',
#  '2016daily142_new.csv',
#  '2016daily143_new.csv',
#  '2016daily144_new.csv',
#  '2016daily146_new.csv',
#  '2016daily147_new.csv',
#  '2016daily148_new.csv',
#  '2016daily150_new.csv',
#  '2016daily151_new.csv',
#  '2016daily152_new.csv',
#  '2016daily153_new.csv',
#  '2016daily155_new.csv',
#  '2016daily157_new.csv',
#  '2016daily158_new.csv',
#  '2016daily159_new.csv',
#  '2016daily160_new.csv',
#  '2016daily161_new.csv',
#  '2016daily163_new.csv',
#  '2016daily165_new.csv',
#  '2016daily167_new.csv',
#  '2016daily169_new.csv',
#  '2016daily170_new.csv',
#  '2016daily171_new.csv',
#  '2016daily173_new.csv',
#  '2016daily174_new.csv',
#  '2016daily175_new.csv',
#  '2016daily178_new.csv',
#  '2016daily179_new.csv',
#  '2016daily181_new.csv',
#  '2016daily182_new.csv',
#  '2016daily183_new.csv',
#  '2016daily184_new.csv',
#  '2016daily187_new.csv',
#  '2016daily188_new.csv',
#  '2016daily189_new.csv',
#  '2016daily190_new.csv',
#  '2016daily191_new.csv',
#  '2016daily192_new.csv',
#  '2016daily193_new.csv',
#  '2016daily194_new.csv',
#  '2016daily195_new.csv',
#  '2016daily196_new.csv',
#  '2016daily197_new.csv',
#  '2016daily198_new.csv',
#  '2016daily199_new.csv',
#  '2016daily200_new.csv',
#  '2016daily202_new.csv',
#  '2016daily203_new.csv',
#  '2016daily204_new.csv',
#  '2016daily205_new.csv',
#  '2016daily206_new.csv',
#  '2016daily207_new.csv',
#  '2016daily208_new.csv',
#  '2016daily209_new.csv',
#  '2016daily210_new.csv',
#  '2016daily211_new.csv',
#  '2016daily212_new.csv',
#  ...]

# %%
fields_str = 'Station_Id,Date,Hour,Julian_Date,Reference_ETo,QC_Reference_ETo,Precipitation,QC_Precipitation,Solar_Radiation,QC_Solar_Radiation,Vapor_Pressure,QC_Vapor_Pressure,Air_Temperature,QC_Air_Temperature,Relative_Humidity,QC_Relative_Humidity,Dew_Point,QC_Dew_Point,Wind_Speed,QC_Wind_Speed,Wind_Direction,QC_Wind_Direction,Soil_Temperature,QC_Soil_Temperature\n'

# %%
fire_data_path
# Out:
# 'c:\\Users\\profc\\Desktop\\Wildfire-Predictor\\dailyStns'

# %%
for file in weather_csv_list:
    file_to_read = fire_data_path + (file[0:4] if file[0:4] != 'dail' else '2016') + '\\' + file
    file_to_write = fire_data_path + (file[0:4] if file[0:4] != 'dail' else '2016') + '\\' + (file[0:4] if file[0:4] != 'dail' else '2016') + 'daily' + (file[9:12] if file[0:4] != 'dail' else file[5:8]) + '_new.csv' 
    f_name = open(file_to_read, 'r')
    f_str = f_name.read()
    mod_str = fields_str + f_str
    
    new_f_name = open(file_to_write, 'w')
    new_f_name.write(mod_str)
    f_name.close()
    new_f_name.close()

# %%
new_weather_csv_list = []
for file in weather_csv_list:
    if file.find('new') != -1:
        new_weather_csv_list.append(file)

# %%
new_weather_csv_list
# Out:
# ['2013daily002_new.csv',
#  '2013daily005_new.csv',
#  '2013daily006_new.csv',
#  '2013daily007_new.csv',
#  '2013daily008_new.csv',
#  '2013daily012_new.csv',
#  '2013daily013_new.csv',
#  '2013daily015_new.csv',
#  '2013daily019_new.csv',
#  '2013daily021_new.csv',
#  '2013daily032_new.csv',
#  '2013daily035_new.csv',
#  '2013daily039_new.csv',
#  '2013daily041_new.csv',
#  '2013daily043_new.csv',
#  '2013daily044_new.csv',
#  '2013daily047_new.csv',
#  '2013daily052_new.csv',
#  '2013daily054_new.csv',
#  '2013daily056_new.csv',
#  '2013daily057_new.csv',
#  '2013daily062_new.csv',
#  '2013daily064_new.csv',
#  '2013daily068_new.csv',
#  '2013daily070_new.csv',
#  '2013daily071_new.csv',
#  '2013daily075_new.csv',
#  '2013daily077_new.csv',
#  '2013daily078_new.csv',
#  '2013daily080_new.csv',
#  '2013daily083_new.csv',
#  '2013daily084_new.csv',
#  '2013daily085_new.csv',
#  '2013daily086_new.csv',
#  '2013daily087_new.csv',
#  '2013daily088_new.csv',
#  '2013daily090_new.csv',
#  '2013daily091_new.csv',
#  '2013daily092_new.csv',
#  '2013daily094_new.csv',
#  '2013daily099_new.csv',
#  '2013daily103_new.csv',
#  '2013daily104_new.csv',
#  '2013daily105_new.csv',
#  '2013daily106_new.csv',
#  '2013daily107_new.csv',
#  '2013daily109_new.csv',
#  '2013daily111_new.csv',
#  '2013daily113_new.csv',
#  '2013daily114_new.csv',
#  '2013daily116_new.csv',
#  '2013daily117_new.csv',
#  '2013daily118_new.csv',
#  '2013daily121_new.csv',
#  '2013daily124_new.csv',
#  '2013daily125_new.csv',
#  '2013daily126_new.csv',
#  '2013daily128_new.csv',
#  '2013daily129_new.csv',
#  '2013daily131_new.csv',
#  '2013daily133_new.csv',
#  '2013daily135_new.csv',
#  '2013daily136_new.csv',
#  '2013daily138_new.csv',
#  '2013daily139_new.csv',
#  '2013daily140_new.csv',
#  '2013daily142_new.csv',
#  '2013daily143_new.csv',
#  '2013daily144_new.csv',
#  '2013daily146_new.csv',
#  '2013daily147_new.csv',
#  '2013daily148_new.csv',
#  '2013daily150_new.csv',
#  '2013daily151_new.csv',
#  '2013daily152_new.csv',
#  '2013daily153_new.csv',
#  '2013daily155_new.csv',
#  '2013daily156_new.csv',
#  '2013daily157_new.csv',
#  '2013daily158_new.csv',
#  '2013daily159_new.csv',
#  '2013daily160_new.csv',
#  '2013daily161_new.csv',
#  '2013daily163_new.csv',
#  '2013daily165_new.csv',
#  '2013daily166_new.csv',
#  '2013daily167_new.csv',
#  '2013daily169_new.csv',
#  '2013daily170_new.csv',
#  '2013daily171_new.csv',
#  '2013daily173_new.csv',
#  '2013daily174_new.csv',
#  '2013daily175_new.csv',
#  '2013daily178_new.csv',
#  '2013daily179_new.csv',
#  '2013daily181_new.csv',
#  '2013daily182_new.csv',
#  '2013daily183_new.csv',
#  '2013daily184_new.csv',
#  '2013daily186_new.csv',
#  '2013daily187_new.csv',
#  '2013daily188_new.csv',
#  '2013daily189_new.csv',
#  '2013daily190_new.csv',
#  '2013daily191_new.csv',
#  '2013daily192_new.csv',
#  '2013daily193_new.csv',
#  '2013daily194_new.csv',
#  '2013daily195_new.csv',
#  '2013daily196_new.csv',
#  '2013daily197_new.csv',
#  '2013daily198_new.csv',
#  '2013daily199_new.csv',
#  '2013daily200_new.csv',
#  '2013daily201_new.csv',
#  '2013daily202_new.csv',
#  '2013daily203_new.csv',
#  '2013daily204_new.csv',
#  '2013daily205_new.csv',
#  '2013daily206_new.csv',
#  '2013daily207_new.csv',
#  '2013daily208_new.csv',
#  '2013daily209_new.csv',
#  '2013daily210_new.csv',
#  '2013daily211_new.csv',
#  '2013daily212_new.csv',
#  '2013daily213_new.csv',
#  '2013daily214_new.csv',
#  '2013daily215_new.csv',
#  '2013daily216_new.csv',
#  '2013daily218_new.csv',
#  '2013daily219_new.csv',
#  '2013daily220_new.csv',
#  '2013daily221_new.csv',
#  '2013daily224_new.csv',
#  '2013daily226_new.csv',
#  '2013daily227_new.csv',
#  '2013daily228_new.csv',
#  '2013daily229_new.csv',
#  '2013daily230_new.csv',
#  '2013daily231_new.csv',
#  '2013daily232_new.csv',
#  '2013daily233_new.csv',
#  '2013daily235_new.csv',
#  '2013daily237_new.csv',
#  '2013daily238_new.csv',
#  '2013daily240_new.csv',
#  '2014daily002_new.csv',
#  '2014daily005_new.csv',
#  '2014daily006_new.csv',
#  '2014daily007_new.csv',
#  '2014daily012_new.csv',
#  '2014daily013_new.csv',
#  '2014daily015_new.csv',
#  '2014daily019_new.csv',
#  '2014daily032_new.csv',
#  '2014daily035_new.csv',
#  '2014daily039_new.csv',
#  '2014daily041_new.csv',
#  '2014daily043_new.csv',
#  '2014daily044_new.csv',
#  '2014daily047_new.csv',
#  '2014daily052_new.csv',
#  '2014daily054_new.csv',
#  '2014daily056_new.csv',
#  '2014daily057_new.csv',
#  '2014daily062_new.csv',
#  '2014daily064_new.csv',
#  '2014daily068_new.csv',
#  '2014daily070_new.csv',
#  '2014daily071_new.csv',
#  '2014daily075_new.csv',
#  '2014daily077_new.csv',
#  '2014daily078_new.csv',
#  '2014daily080_new.csv',
#  '2014daily083_new.csv',
#  '2014daily084_new.csv',
#  '2014daily085_new.csv',
#  '2014daily086_new.csv',
#  '2014daily087_new.csv',
#  '2014daily088_new.csv',
#  '2014daily090_new.csv',
#  '2014daily091_new.csv',
#  '2014daily092_new.csv',
#  '2014daily094_new.csv',
#  '2014daily099_new.csv',
#  '2014daily103_new.csv',
#  '2014daily104_new.csv',
#  '2014daily105_new.csv',
#  '2014daily106_new.csv',
#  '2014daily107_new.csv',
#  '2014daily109_new.csv',
#  '2014daily111_new.csv',
#  '2014daily113_new.csv',
#  '2014daily114_new.csv',
#  '2014daily116_new.csv',
#  '2014daily117_new.csv',
#  '2014daily121_new.csv',
#  '2014daily124_new.csv',
#  '2014daily125_new.csv',
#  '2014daily126_new.csv',
#  '2014daily129_new.csv',
#  '2014daily131_new.csv',
#  '2014daily133_new.csv',
#  '2014daily135_new.csv',
#  '2014daily136_new.csv',
#  '2014daily138_new.csv',
#  '2014daily139_new.csv',
#  '2014daily140_new.csv',
#  '2014daily142_new.csv',
#  '2014daily143_new.csv',
#  '2014daily144_new.csv',
#  '2014daily146_new.csv',
#  '2014daily147_new.csv',
#  '2014daily148_new.csv',
#  '2014daily150_new.csv',
#  '2014daily151_new.csv',
#  '2014daily152_new.csv',
#  '2014daily153_new.csv',
#  '2014daily155_new.csv',
#  '2014daily156_new.csv',
#  '2014daily157_new.csv',
#  '2014daily158_new.csv',
#  '2014daily159_new.csv',
#  '2014daily160_new.csv',
#  '2014daily161_new.csv',
#  '2014daily163_new.csv',
#  '2014daily165_new.csv',
#  '2014daily166_new.csv',
#  '2014daily167_new.csv',
#  '2014daily169_new.csv',
#  '2014daily170_new.csv',
#  '2014daily171_new.csv',
#  '2014daily173_new.csv',
#  '2014daily174_new.csv',
#  '2014daily175_new.csv',
#  '2014daily178_new.csv',
#  '2014daily179_new.csv',
#  '2014daily181_new.csv',
#  '2014daily182_new.csv',
#  '2014daily183_new.csv',
#  '2014daily184_new.csv',
#  '2014daily187_new.csv',
#  '2014daily188_new.csv',
#  '2014daily189_new.csv',
#  '2014daily190_new.csv',
#  '2014daily191_new.csv',
#  '2014daily192_new.csv',
#  '2014daily193_new.csv',
#  '2014daily194_new.csv',
#  '2014daily195_new.csv',
#  '2014daily196_new.csv',
#  '2014daily197_new.csv',
#  '2014daily198_new.csv',
#  '2014daily199_new.csv',
#  '2014daily200_new.csv',
#  '2014daily201_new.csv',
#  '2014daily202_new.csv',
#  '2014daily203_new.csv',
#  '2014daily204_new.csv',
#  '2014daily205_new.csv',
#  '2014daily206_new.csv',
#  '2014daily207_new.csv',
#  '2014daily208_new.csv',
#  '2014daily209_new.csv',
#  '2014daily210_new.csv',
#  '2014daily211_new.csv',
#  '2014daily212_new.csv',
#  '2014daily213_new.csv',
#  '2014daily214_new.csv',
#  '2014daily215_new.csv',
#  '2014daily216_new.csv',
#  '2014daily217_new.csv',
#  '2014daily218_new.csv',
#  '2014daily219_new.csv',
#  '2014daily220_new.csv',
#  '2014daily221_new.csv',
#  '2014daily222_new.csv',
#  '2014daily224_new.csv',
#  '2014daily226_new.csv',
#  '2014daily227_new.csv',
#  '2014daily228_new.csv',
#  '2014daily229_new.csv',
#  '2014daily230_new.csv',
#  '2014daily231_new.csv',
#  '2014daily232_new.csv',
#  '2014daily233_new.csv',
#  '2014daily235_new.csv',
#  '2014daily237_new.csv',
#  '2014daily238_new.csv',
#  '2014daily240_new.csv',
#  '2015daily002_new.csv',
#  '2015daily005_new.csv',
#  '2015daily006_new.csv',
#  '2015daily007_new.csv',
#  '2015daily012_new.csv',
#  '2015daily013_new.csv',
#  '2015daily015_new.csv',
#  '2015daily019_new.csv',
#  '2015daily021_new.csv',
#  '2015daily032_new.csv',
#  '2015daily035_new.csv',
#  '2015daily039_new.csv',
#  '2015daily041_new.csv',
#  '2015daily043_new.csv',
#  '2015daily044_new.csv',
#  '2015daily047_new.csv',
#  '2015daily052_new.csv',
#  '2015daily054_new.csv',
#  '2015daily056_new.csv',
#  '2015daily057_new.csv',
#  '2015daily062_new.csv',
#  '2015daily064_new.csv',
#  '2015daily068_new.csv',
#  '2015daily070_new.csv',
#  '2015daily071_new.csv',
#  '2015daily075_new.csv',
#  '2015daily077_new.csv',
#  '2015daily078_new.csv',
#  '2015daily080_new.csv',
#  '2015daily083_new.csv',
#  '2015daily084_new.csv',
#  '2015daily085_new.csv',
#  '2015daily086_new.csv',
#  '2015daily087_new.csv',
#  '2015daily088_new.csv',
#  '2015daily090_new.csv',
#  '2015daily091_new.csv',
#  '2015daily092_new.csv',
#  '2015daily094_new.csv',
#  '2015daily099_new.csv',
#  '2015daily103_new.csv',
#  '2015daily104_new.csv',
#  '2015daily105_new.csv',
#  '2015daily106_new.csv',
#  '2015daily107_new.csv',
#  '2015daily109_new.csv',
#  '2015daily111_new.csv',
#  '2015daily113_new.csv',
#  '2015daily114_new.csv',
#  '2015daily116_new.csv',
#  '2015daily117_new.csv',
#  '2015daily121_new.csv',
#  '2015daily124_new.csv',
#  '2015daily125_new.csv',
#  '2015daily126_new.csv',
#  '2015daily129_new.csv',
#  '2015daily131_new.csv',
#  '2015daily135_new.csv',
#  '2015daily136_new.csv',
#  '2015daily138_new.csv',
#  '2015daily139_new.csv',
#  '2015daily140_new.csv',
#  '2015daily142_new.csv',
#  '2015daily143_new.csv',
#  '2015daily144_new.csv',
#  '2015daily146_new.csv',
#  '2015daily147_new.csv',
#  '2015daily148_new.csv',
#  '2015daily150_new.csv',
#  '2015daily151_new.csv',
#  '2015daily152_new.csv',
#  '2015daily153_new.csv',
#  '2015daily155_new.csv',
#  '2015daily156_new.csv',
#  '2015daily157_new.csv',
#  '2015daily158_new.csv',
#  '2015daily159_new.csv',
#  '2015daily160_new.csv',
#  '2015daily161_new.csv',
#  '2015daily163_new.csv',
#  '2015daily165_new.csv',
#  '2015daily167_new.csv',
#  '2015daily169_new.csv',
#  '2015daily170_new.csv',
#  '2015daily171_new.csv',
#  '2015daily173_new.csv',
#  '2015daily174_new.csv',
#  '2015daily175_new.csv',
#  '2015daily178_new.csv',
#  '2015daily179_new.csv',
#  '2015daily181_new.csv',
#  '2015daily182_new.csv',
#  '2015daily183_new.csv',
#  '2015daily184_new.csv',
#  '2015daily186_new.csv',
#  '2015daily187_new.csv',
#  '2015daily188_new.csv',
#  '2015daily189_new.csv',
#  '2015daily190_new.csv',
#  '2015daily191_new.csv',
#  '2015daily192_new.csv',
#  '2015daily193_new.csv',
#  '2015daily194_new.csv',
#  '2015daily195_new.csv',
#  '2015daily196_new.csv',
#  '2015daily197_new.csv',
#  '2015daily198_new.csv',
#  '2015daily199_new.csv',
#  '2015daily200_new.csv',
#  '2015daily201_new.csv',
#  '2015daily202_new.csv',
#  '2015daily203_new.csv',
#  '2015daily204_new.csv',
#  '2015daily205_new.csv',
#  '2015daily206_new.csv',
#  '2015daily207_new.csv',
#  '2015daily208_new.csv',
#  '2015daily209_new.csv',
#  '2015daily210_new.csv',
#  '2015daily211_new.csv',
#  '2015daily212_new.csv',
#  '2015daily213_new.csv',
#  '2015daily214_new.csv',
#  '2015daily215_new.csv',
#  '2015daily216_new.csv',
#  '2015daily217_new.csv',
#  '2015daily218_new.csv',
#  '2015daily219_new.csv',
#  '2015daily220_new.csv',
#  '2015daily221_new.csv',
#  '2015daily222_new.csv',
#  '2015daily224_new.csv',
#  '2015daily225_new.csv',
#  '2015daily226_new.csv',
#  '2015daily227_new.csv',
#  '2015daily228_new.csv',
#  '2015daily229_new.csv',
#  '2015daily230_new.csv',
#  '2015daily231_new.csv',
#  '2015daily232_new.csv',
#  '2015daily233_new.csv',
#  '2015daily234_new.csv',
#  '2015daily235_new.csv',
#  '2015daily236_new.csv',
#  '2015daily237_new.csv',
#  '2015daily238_new.csv',
#  '2015daily239_new.csv',
#  '2015daily240_new.csv',
#  '2015daily241_new.csv',
#  '2015daily242_new.csv',
#  '2015daily244_new.csv',
#  '2015daily245_new.csv',
#  '2016daily002_new.csv',
#  '2016daily005_new.csv',
#  '2016daily006_new.csv',
#  '2016daily007_new.csv',
#  '2016daily012_new.csv',
#  '2016daily013_new.csv',
#  '2016daily015_new.csv',
#  '2016daily019_new.csv',
#  '2016daily021_new.csv',
#  '2016daily035_new.csv',
#  '2016daily039_new.csv',
#  '2016daily041_new.csv',
#  '2016daily043_new.csv',
#  '2016daily044_new.csv',
#  '2016daily047_new.csv',
#  '2016daily052_new.csv',
#  '2016daily054_new.csv',
#  '2016daily056_new.csv',
#  '2016daily057_new.csv',
#  '2016daily062_new.csv',
#  '2016daily064_new.csv',
#  '2016daily068_new.csv',
#  '2016daily070_new.csv',
#  '2016daily071_new.csv',
#  '2016daily075_new.csv',
#  '2016daily077_new.csv',
#  '2016daily078_new.csv',
#  '2016daily080_new.csv',
#  '2016daily083_new.csv',
#  '2016daily084_new.csv',
#  '2016daily086_new.csv',
#  '2016daily087_new.csv',
#  '2016daily088_new.csv',
#  '2016daily090_new.csv',
#  '2016daily091_new.csv',
#  '2016daily092_new.csv',
#  '2016daily099_new.csv',
#  '2016daily103_new.csv',
#  '2016daily104_new.csv',
#  '2016daily105_new.csv',
#  '2016daily106_new.csv',
#  '2016daily107_new.csv',
#  '2016daily109_new.csv',
#  '2016daily111_new.csv',
#  '2016daily113_new.csv',
#  '2016daily114_new.csv',
#  '2016daily116_new.csv',
#  '2016daily117_new.csv',
#  '2016daily121_new.csv',
#  '2016daily124_new.csv',
#  '2016daily125_new.csv',
#  '2016daily126_new.csv',
#  '2016daily129_new.csv',
#  '2016daily131_new.csv',
#  '2016daily135_new.csv',
#  '2016daily136_new.csv',
#  '2016daily139_new.csv',
#  '2016daily140_new.csv',
#  '2016daily142_new.csv',
#  '2016daily143_new.csv',
#  '2016daily144_new.csv',
#  '2016daily146_new.csv',
#  '2016daily147_new.csv',
#  '2016daily148_new.csv',
#  '2016daily150_new.csv',
#  '2016daily151_new.csv',
#  '2016daily152_new.csv',
#  '2016daily153_new.csv',
#  '2016daily155_new.csv',
#  '2016daily157_new.csv',
#  '2016daily158_new.csv',
#  '2016daily159_new.csv',
#  '2016daily160_new.csv',
#  '2016daily161_new.csv',
#  '2016daily163_new.csv',
#  '2016daily165_new.csv',
#  '2016daily167_new.csv',
#  '2016daily169_new.csv',
#  '2016daily170_new.csv',
#  '2016daily171_new.csv',
#  '2016daily173_new.csv',
#  '2016daily174_new.csv',
#  '2016daily175_new.csv',
#  '2016daily178_new.csv',
#  '2016daily179_new.csv',
#  '2016daily181_new.csv',
#  '2016daily182_new.csv',
#  '2016daily183_new.csv',
#  '2016daily184_new.csv',
#  '2016daily187_new.csv',
#  '2016daily188_new.csv',
#  '2016daily189_new.csv',
#  '2016daily190_new.csv',
#  '2016daily191_new.csv',
#  '2016daily192_new.csv',
#  '2016daily193_new.csv',
#  '2016daily194_new.csv',
#  '2016daily195_new.csv',
#  '2016daily196_new.csv',
#  '2016daily197_new.csv',
#  '2016daily198_new.csv',
#  '2016daily199_new.csv',
#  '2016daily200_new.csv',
#  '2016daily202_new.csv',
#  '2016daily203_new.csv',
#  '2016daily204_new.csv',
#  '2016daily205_new.csv',
#  '2016daily206_new.csv',
#  '2016daily207_new.csv',
#  '2016daily208_new.csv',
#  '2016daily209_new.csv',
#  '2016daily210_new.csv',
#  '2016daily211_new.csv',
#  '2016daily212_new.csv',
#  '2016daily213_new.csv',
#  '2016daily214_new.csv',
#  '2016daily215_new.csv',
#  '2016daily216_new.csv',
#  '2016daily217_new.csv',
#  '2016daily218_new.csv',
#  '2016daily219_new.csv',
#  '2016daily220_new.csv',
#  '2016daily221_new.csv',
#  '2016daily222_new.csv',
#  '2016daily224_new.csv',
#  '2016daily225_new.csv',
#  '2016daily226_new.csv',
#  '2016daily227_new.csv',
#  '2016daily228_new.csv',
#  '2016daily229_new.csv',
#  '2016daily230_new.csv',
#  '2016daily231_new.csv',
#  '2016daily232_new.csv',
#  '2016daily233_new.csv',
#  '2016daily234_new.csv',
#  '2016daily235_new.csv',
#  '2016daily236_new.csv',
#  '2016daily237_new.csv',
#  '2016daily238_new.csv',
#  '2016daily239_new.csv',
#  '2016daily240_new.csv',
#  '2016daily241_new.csv',
#  '2016daily242_new.csv',
#  '2016daily243_new.csv',
#  '2016daily244_new.csv',
#  '2016daily245_new.csv',
#  '2016daily246_new.csv',
#  '2016daily247_new.csv',
#  '2016daily248_new.csv',
#  '2016daily249_new.csv',
#  '2016daily250_new.csv',
#  '2016daily251_new.csv',
#  '2016daily252_new.csv',
#  '2017daily002_new.csv',
#  '2017daily005_new.csv',
#  '2017daily006_new.csv',
#  '2017daily007_new.csv',
#  '2017daily012_new.csv',
#  '2017daily013_new.csv',
#  '2017daily015_new.csv',
#  '2017daily019_new.csv',
#  '2017daily035_new.csv',
#  '2017daily039_new.csv',
#  '2017daily041_new.csv',
#  '2017daily043_new.csv',
#  '2017daily044_new.csv',
#  '2017daily047_new.csv',
#  '2017daily052_new.csv',
#  '2017daily054_new.csv',
#  '2017daily056_new.csv',
#  '2017daily057_new.csv',
#  '2017daily062_new.csv',
#  '2017daily064_new.csv',
#  '2017daily068_new.csv',
#  '2017daily070_new.csv',
#  '2017daily071_new.csv',
#  '2017daily075_new.csv',
#  '2017daily077_new.csv',
#  '2017daily078_new.csv',
#  '2017daily080_new.csv',
#  '2017daily083_new.csv',
#  '2017daily084_new.csv',
#  '2017daily086_new.csv',
#  '2017daily087_new.csv',
#  '2017daily088_new.csv',
#  '2017daily090_new.csv',
#  '2017daily091_new.csv',
#  '2017daily092_new.csv',
#  '2017daily099_new.csv',
#  '2017daily103_new.csv',
#  '2017daily104_new.csv',
#  '2017daily105_new.csv',
#  '2017daily106_new.csv',
#  '2017daily107_new.csv',
#  '2017daily109_new.csv',
#  '2017daily111_new.csv',
#  '2017daily113_new.csv',
#  '2017daily114_new.csv',
#  '2017daily116_new.csv',
#  '2017daily117_new.csv',
#  '2017daily121_new.csv',
#  '2017daily124_new.csv',
#  '2017daily125_new.csv',
#  '2017daily126_new.csv',
#  '2017daily129_new.csv',
#  '2017daily131_new.csv',
#  '2017daily135_new.csv',
#  '2017daily136_new.csv',
#  '2017daily139_new.csv',
#  '2017daily140_new.csv',
#  '2017daily142_new.csv',
#  '2017daily143_new.csv',
#  '2017daily144_new.csv',
#  '2017daily146_new.csv',
#  '2017daily147_new.csv',
#  '2017daily148_new.csv',
#  '2017daily150_new.csv',
#  '2017daily151_new.csv',
#  '2017daily152_new.csv',
#  '2017daily153_new.csv',
#  '2017daily155_new.csv',
#  '2017daily157_new.csv',
#  '2017daily158_new.csv',
#  '2017daily159_new.csv',
#  '2017daily160_new.csv',
#  '2017daily163_new.csv',
#  '2017daily165_new.csv',
#  '2017daily169_new.csv',
#  '2017daily170_new.csv',
#  '2017daily171_new.csv',
#  '2017daily173_new.csv',
#  '2017daily174_new.csv',
#  '2017daily175_new.csv',
#  '2017daily178_new.csv',
#  '2017daily179_new.csv',
#  '2017daily181_new.csv',
#  '2017daily182_new.csv',
#  '2017daily183_new.csv',
#  '2017daily184_new.csv',
#  '2017daily187_new.csv',
#  '2017daily188_new.csv',
#  '2017daily189_new.csv',
#  '2017daily190_new.csv',
#  '2017daily191_new.csv',
#  '2017daily192_new.csv',
#  '2017daily193_new.csv',
#  '2017daily194_new.csv',
#  '2017daily195_new.csv',
#  '2017daily197_new.csv',
#  '2017daily198_new.csv',
#  '2017daily199_new.csv',
#  '2017daily200_new.csv',
#  '2017daily202_new.csv',
#  '2017daily204_new.csv',
#  '2017daily205_new.csv',
#  '2017daily206_new.csv',
#  '2017daily207_new.csv',
#  '2017daily208_new.csv',
#  '2017daily209_new.csv',
#  '2017daily210_new.csv',
#  '2017daily211_new.csv',
#  '2017daily212_new.csv',
#  '2017daily213_new.csv',
#  '2017daily214_new.csv',
#  '2017daily215_new.csv',
#  '2017daily216_new.csv',
#  '2017daily217_new.csv',
#  '2017daily218_new.csv',
#  '2017daily219_new.csv',
#  '2017daily220_new.csv',
#  '2017daily221_new.csv',
#  '2017daily222_new.csv',
#  '2017daily224_new.csv',
#  '2017daily225_new.csv',
#  '2017daily226_new.csv',
#  '2017daily227_new.csv',
#  '2017daily228_new.csv',
#  '2017daily229_new.csv',
#  '2017daily230_new.csv',
#  '2017daily231_new.csv',
#  '2017daily232_new.csv',
#  '2017daily233_new.csv',
#  '2017daily234_new.csv',
#  '2017daily235_new.csv',
#  '2017daily236_new.csv',
#  '2017daily237_new.csv',
#  '2017daily238_new.csv',
#  '2017daily239_new.csv',
#  '2017daily240_new.csv',
#  '2017daily241_new.csv',
#  '2017daily242_new.csv',
#  '2017daily243_new.csv',
#  '2017daily244_new.csv',
#  '2017daily245_new.csv',
#  '2017daily246_new.csv',
#  '2017daily247_new.csv',
#  '2017daily248_new.csv',
#  '2017daily249_new.csv',
#  '2017daily250_new.csv',
#  '2017daily251_new.csv',
#  '2017daily252_new.csv',
#  '2017daily253_new.csv',
#  '2018daily002_new.csv',
#  '2018daily005_new.csv',
#  '2018daily006_new.csv',
#  '2018daily007_new.csv',
#  '2018daily012_new.csv',
#  '2018daily013_new.csv',
#  '2018daily015_new.csv',
#  '2018daily019_new.csv',
#  '2018daily035_new.csv',
#  '2018daily039_new.csv',
#  '2018daily041_new.csv',
#  '2018daily043_new.csv',
#  '2018daily044_new.csv',
#  '2018daily047_new.csv',
#  '2018daily052_new.csv',
#  '2018daily054_new.csv',
#  '2018daily056_new.csv',
#  '2018daily057_new.csv',
#  '2018daily062_new.csv',
#  '2018daily064_new.csv',
#  '2018daily068_new.csv',
#  '2018daily070_new.csv',
#  '2018daily071_new.csv',
#  '2018daily075_new.csv',
#  '2018daily077_new.csv',
#  '2018daily078_new.csv',
#  '2018daily080_new.csv',
#  '2018daily083_new.csv',
#  '2018daily084_new.csv',
#  '2018daily086_new.csv',
#  '2018daily087_new.csv',
#  '2018daily088_new.csv',
#  '2018daily090_new.csv',
#  '2018daily091_new.csv',
#  '2018daily092_new.csv',
#  '2018daily099_new.csv',
#  '2018daily103_new.csv',
#  '2018daily104_new.csv',
#  '2018daily105_new.csv',
#  '2018daily107_new.csv',
#  '2018daily109_new.csv',
#  '2018daily111_new.csv',
#  '2018daily113_new.csv',
#  '2018daily114_new.csv',
#  '2018daily116_new.csv',
#  '2018daily117_new.csv',
#  '2018daily121_new.csv',
#  '2018daily124_new.csv',
#  '2018daily125_new.csv',
#  '2018daily126_new.csv',
#  '2018daily129_new.csv',
#  '2018daily131_new.csv',
#  '2018daily135_new.csv',
#  '2018daily136_new.csv',
#  '2018daily139_new.csv',
#  '2018daily140_new.csv',
#  '2018daily142_new.csv',
#  '2018daily143_new.csv',
#  '2018daily144_new.csv',
#  '2018daily146_new.csv',
#  '2018daily147_new.csv',
#  '2018daily148_new.csv',
#  '2018daily150_new.csv',
#  '2018daily151_new.csv',
#  '2018daily152_new.csv',
#  '2018daily153_new.csv',
#  '2018daily155_new.csv',
#  '2018daily157_new.csv',
#  '2018daily158_new.csv',
#  '2018daily159_new.csv',
#  '2018daily160_new.csv',
#  '2018daily163_new.csv',
#  '2018daily165_new.csv',
#  '2018daily169_new.csv',
#  '2018daily170_new.csv',
#  '2018daily171_new.csv',
#  '2018daily173_new.csv',
#  '2018daily174_new.csv',
#  '2018daily175_new.csv',
#  '2018daily178_new.csv',
#  '2018daily179_new.csv',
#  '2018daily181_new.csv',
#  '2018daily182_new.csv',
#  '2018daily183_new.csv',
#  '2018daily184_new.csv',
#  '2018daily187_new.csv',
#  '2018daily189_new.csv',
#  '2018daily190_new.csv',
#  '2018daily191_new.csv',
#  '2018daily192_new.csv',
#  '2018daily193_new.csv',
#  '2018daily194_new.csv',
#  '2018daily195_new.csv',
#  '2018daily197_new.csv',
#  '2018daily198_new.csv',
#  '2018daily199_new.csv',
#  '2018daily200_new.csv',
#  '2018daily202_new.csv',
#  '2018daily204_new.csv',
#  '2018daily205_new.csv',
#  '2018daily206_new.csv',
#  '2018daily207_new.csv',
#  '2018daily208_new.csv',
#  '2018daily209_new.csv',
#  '2018daily210_new.csv',
#  '2018daily211_new.csv',
#  '2018daily212_new.csv',
#  '2018daily213_new.csv',
#  '2018daily214_new.csv',
#  '2018daily215_new.csv',
#  '2018daily216_new.csv',
#  '2018daily217_new.csv',
#  '2018daily218_new.csv',
#  '2018daily219_new.csv',
#  '2018daily220_new.csv',
#  '2018daily221_new.csv',
#  '2018daily222_new.csv',
#  '2018daily223_new.csv',
#  '2018daily224_new.csv',
#  '2018daily225_new.csv',
#  '2018daily226_new.csv',
#  '2018daily227_new.csv',
#  '2018daily228_new.csv',
#  '2018daily229_new.csv',
#  '2018daily231_new.csv',
#  '2018daily232_new.csv',
#  '2018daily233_new.csv',
#  '2018daily234_new.csv',
#  '2018daily235_new.csv',
#  '2018daily236_new.csv',
#  '2018daily237_new.csv',
#  '2018daily239_new.csv',
#  '2018daily240_new.csv',
#  '2018daily241_new.csv',
#  '2018daily242_new.csv',
#  '2018daily243_new.csv',
#  '2018daily244_new.csv',
#  '2018daily245_new.csv',
#  '2018daily246_new.csv',
#  '2018daily247_new.csv',
#  '2018daily248_new.csv',
#  '2018daily249_new.csv',
#  '2018daily250_new.csv',
#  '2018daily251_new.csv',
#  '2018daily252_new.csv',
#  '2018daily253_new.csv',
#  '2018daily254_new.csv',
#  '2018daily255_new.csv',
#  '2018daily256_new.csv',
#  '2018daily257_new.csv',
#  '2019daily002_new.csv',
#  '2019daily005_new.csv',
#  '2019daily006_new.csv',
#  '2019daily007_new.csv',
#  '2019daily012_new.csv',
#  '2019daily013_new.csv',
#  '2019daily015_new.csv',
#  '2019daily035_new.csv',
#  '2019daily039_new.csv',
#  '2019daily041_new.csv',
#  '2019daily043_new.csv',
#  '2019daily044_new.csv',
#  '2019daily047_new.csv',
#  '2019daily052_new.csv',
#  '2019daily054_new.csv',
#  '2019daily056_new.csv',
#  '2019daily057_new.csv',
#  '2019daily062_new.csv',
#  '2019daily064_new.csv',
#  '2019daily068_new.csv',
#  '2019daily070_new.csv',
#  '2019daily071_new.csv',
#  '2019daily075_new.csv',
#  '2019daily077_new.csv',
#  '2019daily078_new.csv',
#  '2019daily080_new.csv',
#  '2019daily083_new.csv',
#  '2019daily084_new.csv',
#  '2019daily086_new.csv',
#  '2019daily087_new.csv',
#  '2019daily088_new.csv',
#  '2019daily090_new.csv',
#  '2019daily091_new.csv',
#  '2019daily092_new.csv',
#  '2019daily099_new.csv',
#  '2019daily103_new.csv',
#  '2019daily104_new.csv',
#  '2019daily105_new.csv',
#  '2019daily106_new.csv',
#  '2019daily107_new.csv',
#  '2019daily109_new.csv',
#  '2019daily111_new.csv',
#  '2019daily113_new.csv',
#  '2019daily114_new.csv',
#  '2019daily116_new.csv',
#  '2019daily117_new.csv',
#  '2019daily121_new.csv',
#  '2019daily124_new.csv',
#  '2019daily125_new.csv',
#  '2019daily126_new.csv',
#  '2019daily129_new.csv',
#  '2019daily131_new.csv',
#  '2019daily135_new.csv',
#  '2019daily136_new.csv',
#  '2019daily139_new.csv',
#  '2019daily140_new.csv',
#  '2019daily142_new.csv',
#  '2019daily143_new.csv',
#  '2019daily144_new.csv',
#  '2019daily146_new.csv',
#  '2019daily147_new.csv',
#  '2019daily148_new.csv',
#  '2019daily150_new.csv',
#  '2019daily151_new.csv',
#  '2019daily152_new.csv',
#  '2019daily153_new.csv',
#  '2019daily155_new.csv',
#  '2019daily157_new.csv',
#  '2019daily158_new.csv',
#  '2019daily159_new.csv',
#  '2019daily160_new.csv',
#  '2019daily163_new.csv',
#  '2019daily165_new.csv',
#  '2019daily169_new.csv',
#  '2019daily170_new.csv',
#  '2019daily171_new.csv',
#  '2019daily173_new.csv',
#  '2019daily174_new.csv',
#  '2019daily175_new.csv',
#  '2019daily178_new.csv',
#  '2019daily179_new.csv',
#  '2019daily181_new.csv',
#  '2019daily182_new.csv',
#  '2019daily183_new.csv',
#  '2019daily184_new.csv',
#  '2019daily187_new.csv',
#  '2019daily189_new.csv',
#  '2019daily191_new.csv',
#  '2019daily192_new.csv',
#  '2019daily193_new.csv',
#  '2019daily194_new.csv',
#  '2019daily195_new.csv',
#  '2019daily197_new.csv',
#  '2019daily198_new.csv',
#  '2019daily199_new.csv',
#  '2019daily200_new.csv',
#  '2019daily202_new.csv',
#  '2019daily204_new.csv',
#  '2019daily205_new.csv',
#  '2019daily206_new.csv',
#  '2019daily207_new.csv',
#  '2019daily208_new.csv',
#  '2019daily209_new.csv',
#  '2019daily210_new.csv',
#  '2019daily211_new.csv',
#  ...]

# %%
df = pd.read_csv(fire_data_path + new_weather_csv_list[0][0:4] + '\\' + new_weather_csv_list[0])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 df = pd.read_csv(fire_data_path + new_weather_csv_list[0][0:4] + '\\' + new_weather_csv_list[0])
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1772, in TextFileReader.read(self, nrows)
#    1765 nrows = validate_integer("nrows", nrows)
#    1766 try:
#    1767     # error: "ParserBase" has no attribute "read"
#    1768     (
#    1769         index,
#    1770         columns,
#    1771         col_dict,
# -> 1772     ) = self._engine.read(  # type: ignore[attr-defined]
#    1773         nrows
#    1774     )
#    1775 except Exception:
#    1776     self.close()
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:243, in CParserWrapper.read(self, nrows)
#     241 try:
#     242     if self.low_memory:
# --> 243         chunks = self._reader.read_low_memory(nrows)
#     244         # destructive to chunks
#     245         data = _concatenate_chunks(chunks)
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\profc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 24 fields in line 3, saw 31

# %%
station_list = pd.read_excel("CIMIS Stations List (January20).xlsx")

# %%
station_list = station_list.loc[station_list['Status'] == 'Active']
station_list
# Out:
#      Station Number DWR Regional Office*              Name    County  \
# 1               2.0                 SCRO     Five Points      Fresno
# 4               5.0                 SCRO      Shafter/USDA      Kern
# 5               6.0                 NCRO             Davis      Yolo
# 6               7.0                 SCRO  Firebaugh/Telles    Fresno
# 11             12.0                  NRO            Durham     Butte
# ..              ...                  ...               ...       ...
# 256           257.0                  SRO        Ridgecrest      Kern
# 257           258.0                 SCRO        Lemon Cove    Tulare
# 258           259.0                  NRO    Ferndale Plain  Humboldt
# 259           260.0                  NRO          Montague  Siskiyou
# 260           261.0                  NRO           Gazelle  Siskiyou
#
#       Latitude   Longitude    ELEV  Status    Connect Disconnect
# 1    36.336222 -120.112906   285.0  Active 1982-06-07     Active
# 4    35.532695 -119.281862   360.0  Active 1982-06-01     Active
# 5    38.535794 -121.776385    60.0  Active 1982-07-17     Active
# 6    36.851248 -120.590980   185.0  Active 1982-09-22     Active
# 11   39.608639 -121.824431   130.0  Active 1982-10-19     Active
# ..         ...         ...     ...     ...        ...        ...
# 256  35.659128 -117.636925  2234.0  Active 2018-10-10     Active
# 257  36.376917 -119.037972   498.0  Active 2018-11-15     Active
# 258  40.604467 -124.243186    21.0  Active 2019-08-05     Active
# 259  41.798331 -122.463425  2663.0  Active 2019-09-20     Active
# 260  41.533989 -122.532279  2743.0  Active 2019-09-18     Active
#
# [154 rows x 10 columns]

# %%
fire_csv
# Out:
#         ID  AcresBurned  ArchiveYear     Counties          Extinguished  \
# 0        0     257314.0         2013     Tuolumne  2013-09-06T18:30:00Z
# 1        1      30274.0         2013  Los Angeles  2013-06-08T18:30:00Z
# 2        2      27531.0         2013    Riverside  2013-07-30T18:00:00Z
# 3        4      24251.0         2013      Ventura  2013-05-11T06:30:00Z
# 4        6      20292.0         2013    Riverside  2013-08-12T18:00:00Z
# ...    ...          ...          ...          ...                   ...
# 1246  1628         10.0         2019        Butte                   NaN
# 1247  1629         10.0         2019     Siskiyou  2019-06-21T14:23:00Z
# 1248  1630         10.0         2019        Butte  2019-05-08T08:47:00Z
# 1249  1631          9.0         2019    Riverside  2019-10-10T18:11:00Z
# 1250  1632          2.0         2019       Nevada  2019-06-28T17:33:00Z
#
#       Fatalities  Injuries   Latitude   Longitude             Name  \
# 0            0.0       0.0  37.857000 -120.086000         Rim Fire
# 1            0.0       0.0  34.585595 -118.423176  Powerhouse Fire
# 2            0.0       0.0  33.709500 -116.728850    Mountain Fire
# 3            0.0      10.0   0.000000    0.000000     Springs Fire
# 4            0.0      26.0  33.861570 -116.904270      Silver Fire
# ...          ...       ...        ...         ...              ...
# 1246         0.0       0.0  39.423833 -121.579738       Moms Fire
# 1247         0.0       0.0  41.946220 -122.401570    IronGate Fire
# 1248         0.0       0.0  39.839580 -121.957000        Cana Fire
# 1249         0.0       0.0  33.827979 -117.499619       Eagle Fire
# 1250         0.0       0.0  39.409722 -121.000556        Long Fire
#
#                    Started
# 0     2013-08-17T15:25:00Z
# 1     2013-05-30T15:28:00Z
# 2     2013-07-15T13:43:00Z
# 3     2013-05-02T07:01:00Z
# 4     2013-08-07T14:05:00Z
# ...                    ...
# 1246  2019-07-23T14:41:00Z
# 1247  2019-06-16T20:33:00Z
# 1248  2019-04-30T12:20:00Z
# 1249  2019-10-10T12:08:00Z
# 1250  2019-06-28T15:03:04Z
#
# [1251 rows x 11 columns]

# %%
date_str = fire_csv.iat[0, 10][0:10].split('-')
date_str
# Out:
# ['2013', '08', '17']

# %%
county_name = fire_csv.iat[0,3]
county_name
# Out:
# 'Tuolumne'

# %%
station_list['County'] == county_name
# Out:
# 1      False
# 4      False
# 5      False
# 6      False
# 11     False
#        ...
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# Name: County, Length: 154, dtype: bool

# %%
stations = pd.read_excel("CIMIS Stations List (January20).xlsx")
stations = stations.drop(261)
stations = stations.drop(["DWR Regional Office*", "Name", "Status", "ELEV"], 1)
stations["Connect"] = pd.to_datetime(stations["Connect"]).dt.date
stations.replace("Active", dt.datetime.now(), inplace=True)
stations["Disconnect"] = pd.to_datetime(stations["Disconnect"]).dt.date
stations
# Out:
# C:\Users\profc\AppData\Local\Temp\ipykernel_3556\3340084584.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   stations = stations.drop(["DWR Regional Office*", "Name", "Status", "ELEV"], 1)
#      Station Number      County   Latitude   Longitude     Connect  Disconnect
# 0               1.0      Fresno  36.814000 -119.732000  1982-06-07  1988-09-25
# 1               2.0      Fresno  36.336222 -120.112906  1982-06-07  2022-10-16
# 2               3.0  Santa Cruz  36.881000 -121.793000  1982-05-30  1986-08-25
# 3               4.0  Santa Cruz  36.972000 -121.726000  1982-05-30  1988-04-29
# 4               5.0        Kern  35.532695 -119.281862  1982-06-01  2022-10-16
# ..              ...         ...        ...         ...         ...         ...
# 256           257.0        Kern  35.659128 -117.636925  2018-10-10  2022-10-16
# 257           258.0      Tulare  36.376917 -119.037972  2018-11-15  2022-10-16
# 258           259.0    Humboldt  40.604467 -124.243186  2019-08-05  2022-10-16
# 259           260.0    Siskiyou  41.798331 -122.463425  2019-09-20  2022-10-16
# 260           261.0    Siskiyou  41.533989 -122.532279  2019-09-18  2022-10-16
#
# [261 rows x 6 columns]

# %%
# Gets a station number given a location and date
# If the location is (0, 0), returns the first station found in that county
# If there is no station active for the given date, returns -1
def getStationNumber(lat, long, day, county):
    
    if not (lat or long):
        for i in range(len(stations.index)):
            if stations.loc[i, "County"] == county and (stations["Connect"][i] <= day and stations["Disconnect"][i] >= day):
                return stations["Station Number"][i]

    minStation = -1
    minDistSquare = -1

    for i in range(len(stations.index)):
        if stations["Connect"][i] <= day and day <= stations["Disconnect"][i]:
            minStation = stations["Station Number"][0]
            initLat = stations.loc[0, "Latitude"]
            initLong = stations.loc[0, "Longitude"]
            minDistanceSquare = (initLat - lat)**2 + (initLong - long)**2
    
    if minStation == -1:
        return -1

    for i in range(1, len(stations.index)):
        statLat = stations.loc[i, "Latitude"]
        statLong = stations.loc[i, "Longitude"]
        if (statLat-lat)**2 + (statLong-long)**2 < minDistanceSquare and stations["Connect"][i] <= day and day <= stations["Disconnect"][i]:
            minStation = stations["Station Number"][i]
            minDistanceSquare = (statLat-lat)**2 + (statLong-long)**2
    
    return minStation

# %%
fire_data_path
# Out:
# 'c:\\Users\\profc\\Desktop\\Wildfire-Predictor\\dailyStns'

# %%
# Retreives relevant weather data for a given station on a given date
# Assumes the station is active on the date
# Returns a tuple with the following values
#    (Precipitation, Air Temperature, Humidity)
def getData(statNumber, date: dt.date):
    # Creating and cleaning the dataframe
    path = "dailyStns" + str(date.year) + '/' + str(date.year) + "daily" + str(statNumber).zfill(3) + ".csv"
    weather = pd.read_csv(path, header=None)
    weather.columns = ["Station", "Date", "Julian Date", "Reference ETo", "QC for Reference ETo", "Precipitation", "QC for Precipitation", "Solar Radiation", "QC for Solar Radiation", "Vapor Pressure", "QC for Vapor Pressure", "Maximum Air Temperature", "QC for Maximum Air Temperature", "Minimum Air Temperature", "QC for Minimum Air Temperature", "Average Air Temperature", "QC for Average Air Temperature", "Maximum Relative Humidity", "QC for Maximum Relative Humidity", "Minimum Relative Humidity", "QC for Minimum Relative Humidity", "Average Relative Humidity", "QC for Average Relative Humidity", "Dew Point", "QC for Dew Point", "Wind Speed", "QC for Wind Speed", "Wind Run", "QC for Wind Run", "Average Soil Temperature", "QC for Average Soil Temperature"]
    for i in range(len(weather.index)):
        if dt.datetime.strptime(weather["Date"][i], "%d/%m/%Y").date() == date:
            return (weather["Precipitation"][i], weather["Average Air Temperature"][i], weather["Average Relative Humidity"][i])

# %%
# Testing for the error
fires = pd.read_csv("Updated_long_late_fire_data.csv")
# fires[fires["Name"] == "Long Fire"]
# fires.groupby(["Name"]).first()
for i in range(len(fires.index)):
    print(i, fires["Name"][i])
# Out:
# 0 Rim Fire
# 1 Powerhouse Fire
# 2 Mountain Fire
# 3 Silver Fire
# 4 Deer Fire
# 5 Clover Fire
# 6 Panther Fire
# 7 Grand Fire
# 8 Grand Fire
# 9 McCabe Fire
# 10 Summit Fire
# 11 Morgan Fire
# 12 Swedes Fire
# 13 Carstens Fire
# 14 Falls Fire
# 15 Rancho Fire
# 16 Lake Fire
# 17 Water Fire
# 18 Mills Fire
# 19 Gorgonio Fire
# 20 Fox Fire (formally 3-7 Fire)
# 21 Kirker Fire
# 22 Rolling Fire
# 23 River Fire
# 24 Putah Fire
# 25 Tres Pinos Fire
# 26 Summit Fire
# 27 Shelton Fire
# 28 Lone Fire
# 29 Concord Fire
# 30 Gold Fire
# 31 Vasco Fire
# 32 PFE Fire
# 33 306 Fire
# 34 Vina Fire
# 35 Burney Lightning Series (Warner Fire)
# 36 Paskenta Fire
# 37 Silverado Fire
# 38 Olive Fire
# 39 Capay Fire
# 40 50 Fire
# 41 50 Fire
# 42 Crane Fire
# 43 Lakeville Fire
# 44 Redlands Fire
# 45 Diablo Fire
# 46 George Fire
# 1056 Carroll Fire
# 1057 Del Fire
# 1058 Foster Fire
# 1059 Mines Fire
# 1060 32 Fire
# 1061 Rocky Fire
# 1062 Cow Fire
# 1063 Greenstone Fire
# 1064 Duzel Fire
# 1065 Telephone Fire
# 1066 Carson Fire
# 1067 Little Fire
# 1068 Mayberry Fire
# 1069 Beaumont Fire
# 1070 Dales Fire
# 1071 Bridge Fire
# 1072 Mines Fire
# 1073 Inghram Fire
# 1074 Electra Fire
# 1075 Bailey Fire
# 1076 Moms Fire
# 1077 IronGate Fire
# 1078 Cana Fire
# 1079 Eagle Fire
# 1080 Long Fire

# %%
fires = pd.read_csv("Updated_long_late_fire_data.csv")
fires = fires.drop(columns=["Unnamed: 0", "ArchiveYear"]) #, "Name"
fires = fires.dropna()
fires["Precipitation30"] = None
fires["Precipitation60"] = None
fires["Precipitation90"] = None
fires["Temperature30"] = None
fires["Temperature60"] = None
fires["Temperature90"] = None
fires["Humidity30"] = None
fires["Humidity60"] = None
fires["Humidity90"] = None

for i in range(len(fires.index)):
    year = int(fires["Started"][i][:4])
    month = int(fires["Started"][i][5:7])
    day = int(fires["Started"][i][8:10])
    print(i,year, month, day, fires["Name"][i])
    day = dt.date(year, month, day)
# Out:
# 0 2013 8 17 Rim Fire
# 1 2013 5 30 Powerhouse Fire
# 2 2013 7 15 Mountain Fire
# 3 2013 8 7 Silver Fire
# 4 2013 8 23 Deer Fire
# 5 2013 9 9 Clover Fire
# 6 2013 5 1 Panther Fire
# 7 2013 5 15 Grand Fire
# 8 2013 5 15 Grand Fire
# 9 2013 11 22 McCabe Fire
# 10 2013 5 1 Summit Fire
# 11 2013 9 8 Morgan Fire
# 12 2013 8 16 Swedes Fire
# 13 2013 6 16 Carstens Fire
# 14 2013 8 5 Falls Fire
# 15 2013 7 19 Rancho Fire
# 16 2013 5 17 Lake Fire
# 17 2013 7 23 Water Fire
# 18 2013 6 28 Mills Fire
# 19 2013 5 4 Gorgonio Fire
# 20 2013 7 3 Fox Fire (formally 3-7 Fire)
# 21 2013 7 1 Kirker Fire
# 22 2013 6 16 Rolling Fire
# 23 2013 2 24 River Fire
# 24 2013 10 3 Putah Fire
# 25 2013 5 3 Tres Pinos Fire
# 26 2013 10 4 Summit Fire
# 27 2013 5 30 Shelton Fire
# 28 2013 6 3 Lone Fire
# 29 2013 7 1 Concord Fire
# 30 2013 4 30 Gold Fire
# 31 2013 6 8 Vasco Fire
# 32 2013 6 13 PFE Fire
# 33 2013 5 1 306 Fire
# 34 2013 7 4 Vina Fire
# 35 2013 8 19 Burney Lightning Series (Warner Fire)
# 36 2013 7 19 Paskenta Fire
# 37 2013 11 21 Silverado Fire
# 38 2013 5 28 Olive Fire
# 39 2013 11 4 Capay Fire
# 40 2013 7 19 50 Fire
# 41 2013 7 19 50 Fire
# 42 2013 10 4 Crane Fire
# 43 2013 7 26 Lakeville Fire
# 44 2013 7 16 Redlands Fire
# 45 2013 7 12 Diablo Fire
# 46 2013 6 25 George Fire
# 47 2013 5 28 Magic Fire
# 845 2018 9 23 Quimby Fire
# 846 2018 8 4 Creek Fire
# 847 2018 7 28 Sobrante Fire
# 848 2018 7 21 Rock Fire
# 849 2018 6 29 Grant Fire
# 850 2018 4 12 Aqueduct Fire
# 851 2018 5 19 Ager Fire
# 852 2018 5 18 White Fire
# 853 2018 6 16 Willow Fire
# 854 2018 5 29 Vineyard Fire
# 855 2018 9 3 Kelsey Fire
# 856 2018 8 22 Land Fire
# 857 2018 6 2 Glen Fire
# 858 2018 6 1 Plymire Fire
# 859 2018 8 4 Wagner Fire
# 860 2018 4 9 Meadow Fire
# 861 2018 11 15 Morgan Fire
# 862 2018 11 14 Niles Fire
# 863 2018 7 25 Church Fire
# 864 2018 6 17 Vallecitos Fire
# 865 2018 6 14 Bridle Fire
# 866 2018 6 14 70 Fire
# 867 2018 4 22 Lago Fire
# 868 2018 11 3 Rincon Fire
# 869 2018 6 17 China Fire
# 870 2018 6 3 Ethanac Fire
# 871 2018 8 12 Oak Fire
# 872 2018 7 15 Johnson Fire
# 873 2018 5 27 Keeler Fire
# 874 2018 10 10 Iron Gate Fire
# 875 2018 5 4 Woodchuck Fire
# 876 2018 4 15 Tyler Fire
# 877 2018 7 17 Camp Fire
# 878 2018 7 14 3-2 Fire
# 879 2018 6 1 Madison FIre
# 880 2018 6 2 Coldwell Fire
# 881 2018 10 14 Tower Fire
# 882 2018 9 20 Meyers Fire
# 883 2018 7 13 Gray Fire
# 884 2018 7 10 School Fire
# 885 2018 6 5 Vista Fire
# 886 2018 6 4 Meamber Fire
# 887 2018 6 3 Resort Fire
# 888 2018 5 21 Bellagio Fire
# 889 2018 5 14 Grant Fire
# 890 2018 7 10 Dark Fire
# 891 2018 7 9 Cornerstone Fire
# 892 2018 6 3 Grande Fire
# 893 2018 3 27 Rock Fire
# 894 2018 11 16 Bear Fire
# 895 2018 11 12 Green Hill Fire
# 896 2018 10 15 Powellton Fire
# 897 2018 8 19 Keller Fire
# 898 2018 8 9 Syar Fire
# 899 2018 7 17 Lott Fire
# 900 2018 6 29 Llano Fire
# 901 2018 6 21 Creek Fire
# 902 2018 6 19 Ranchita Fire
# 903 2018 6 3 Black Fire
# 904 2018 6 2 Jardin Fire
# 905 2018 5 28 70th Fire
# 906 2018 11 29 Honey Flooding
# 907 2019 10 30 Easy Fire
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 908
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 14>()
#      12 fires["Humidity90"] = None
#      14 for i in range(len(fires.index)):
# ---> 15     year = int(fires["Started"][i][:4])
#      16     month = int(fires["Started"][i][5:7])
#      17     day = int(fires["Started"][i][8:10])
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 908
